# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
loss = pd.read_csv("loss.csv")

# %%
plt.plot(loss["Step"], loss["GPT"])
plt.plot(loss["Step"], loss["SVD"])
plt.plot(loss["Step"], loss["Sketching"])
plt.xlabel("step")
plt.ylabel("loss")
plt.legend(("GPT", "SVD", "Sketching"))

# %%
plt.plot(loss["Step"], loss["GPT"])
plt.plot(loss["Step"], loss["SVD"])
plt.xlabel("step")
plt.ylabel("loss")
plt.legend(("GPT", "SVD", "Sketching"))
